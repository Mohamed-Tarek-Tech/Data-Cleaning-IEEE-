# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("all_bikez_curated (1).csv")
data
# Out:
# C:\Users\BG\AppData\Local\Temp\ipykernel_6324\602475079.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("all_bikez_curated (1).csv")
#          Brand                Model  Year                   Category  \
# 0      acabion      da vinci 650-vi  2011  Prototype / concept model
# 1      acabion              gtbo 55  2007                      Sport
# 2      acabion  gtbo 600 daytona-vi  2011  Prototype / concept model
# 3      acabion  gtbo 600 daytona-vi  2021  Prototype / concept model
# 4      acabion              gtbo 70  2007  Prototype / concept model
# ...        ...                  ...   ...                        ...
# 38538     azel             aries 50  2009                    Scooter
# 38539     azel             aries 50  2010                    Scooter
# 38540     azel            atila 125  2009           Enduro / offroad
# 38541     azel            atila 125  2010           Enduro / offroad
# ...

# %%
# Show the mising values in our data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38543 entries, 0 to 38542
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Brand                38543 non-null  object
#  1   Model                38515 non-null  object
#  2   Year                 38543 non-null  object
#  3   Category             38543 non-null  object
#  4   Displacement (ccm)   37514 non-null  float64
#  5   Power (hp)           26162 non-null  float64
#  6   Engine cylinder      38527 non-null  object
#  7   Engine stroke        38532 non-null  object
#  8   Gearbox              32733 non-null  object
#  9   Fuel capacity (lts)  31747 non-null  float64
#  10  Fuel system          27893 non-null  object
#  11  Fuel control         22032 non-null  object
#  12  Cooling system       34322 non-null  object
#  13  Transmission type    32912 non-null  object
#  14  Dry weight (kg)      22534 non-null  float64
# ...

# %%
data.shape
# Out:
# (38543, 17)

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 38538    False
# 38539    False
# 38540    False
# 38541    False
# 38542    False
# Length: 38543, dtype: bool

# %%
columns_names = data.columns
columns_names
# Out:
# Index(['Brand', 'Model', 'Year', 'Category', 'Displacement (ccm)',
#        'Power (hp)', 'Engine cylinder', 'Engine stroke', 'Gearbox',
#        'Fuel capacity (lts)', 'Fuel system', 'Fuel control', 'Cooling system',
#        'Transmission type', 'Dry weight (kg)', 'Wheelbase (mm)',
#        'Seat height (mm)'],
#       dtype='object')

# %%
Duplicate = data.duplicated(subset =columns_names, keep = False )
Duplicate
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 38538    False
# 38539    False
# 38540    False
# 38541    False
# 38542    False
# Length: 38543, dtype: bool

# %%
data.drop_duplicates(inplace = True)
print("Duplicated Data Is Deleted")
# Out:
# Duplicated Data Is Deleted

# %%
data.head()
# Out:
#      Brand                Model  Year                   Category  \
# 0  acabion      da vinci 650-vi  2011  Prototype / concept model
# 1  acabion              gtbo 55  2007                      Sport
# 2  acabion  gtbo 600 daytona-vi  2011  Prototype / concept model
# 3  acabion  gtbo 600 daytona-vi  2021  Prototype / concept model
# 4  acabion              gtbo 70  2007  Prototype / concept model
#
#    Displacement (ccm)  Power (hp) Engine cylinder Engine stroke  Gearbox  \
# 0                 NaN       804.0        Electric      Electric      NaN
# 1              1300.0       541.0    In-line four   four-stroke  6-speed
# 2                 NaN       536.0        Electric      Electric      NaN
# 3                 NaN       536.0        Electric      Electric      NaN
# 4              1300.0       689.0    In-line four   four-stroke  6-speed
#
#    Fuel capacity (lts)                  Fuel system Fuel control  \
# 0                  NaN                          NaN          NaN
# ...

# %%
data.shape
# Out:
# (38535, 17)

# %%
data.describe()
# Out:
#        Displacement (ccm)    Power (hp)  Fuel capacity (lts)  Dry weight (kg)  \
# count        37506.000000  26155.000000         31742.000000     22528.000000
# mean           552.398731     50.746687            13.284605       164.110121
# std            545.370040     52.071711             6.009841        85.062192
# min             25.000000      0.300000             0.500000        15.100000
# 25%            125.000000     12.000000             8.200000       105.000000
# 50%            397.000000     30.000000            13.500000       145.000000
# 75%            805.000000     77.000000            17.500000       199.600000
# max           8277.000000    804.000000            64.340000      1000.000000
#
#        Wheelbase (mm)  Seat height (mm)
# count    25528.000000      24224.000000
# mean      1423.008383        789.289217
# std        172.591933        105.439955
# min        725.000000         39.000000
# 25%       1321.000000        744.000000
# ...

# %%
data['Model'].value_counts(dropna=False)
# Out:
# Model
# servi-car ge          38
# chief                 32
# speed twin            28
# NaN                   28
# vh 500 red hunter     27
#                       ..
# scrambler 1100 pro     1
# fun 125 plus           1
# fun 125 pluss          1
# lord martin            1
# da vinci 650-vi        1
# Name: count, Length: 17730, dtype: int64

# %%
d1 = data['Model'].unique()
d1
# Out:
# array(['da vinci 650-vi', 'gtbo 55', 'gtbo 600 daytona-vi', ..., 'z 22',
#        'z 249', 'z 300'], dtype=object)

# %%
data.dropna(subset = 'Model', inplace = True)

# %%
data['Model'].value_counts(dropna=False)
# Out:
# Model
# servi-car ge          38
# chief                 32
# speed twin            28
# rt 2                  27
# vh 500 red hunter     27
#                       ..
# scrambler 1100 pro     1
# fun 125 plus           1
# fun 125 pluss          1
# lord martin            1
# da vinci 650-vi        1
# Name: count, Length: 17729, dtype: int64

# %%
data.shape
# Out:
# (38507, 17)

# %%
data.head()
# Out:
#      Brand                Model  Year                   Category  \
# 0  acabion      da vinci 650-vi  2011  Prototype / concept model
# 1  acabion              gtbo 55  2007                      Sport
# 2  acabion  gtbo 600 daytona-vi  2011  Prototype / concept model
# 3  acabion  gtbo 600 daytona-vi  2021  Prototype / concept model
# 4  acabion              gtbo 70  2007  Prototype / concept model
#
#    Displacement (ccm)  Power (hp) Engine cylinder Engine stroke  Gearbox  \
# 0                 NaN       804.0        Electric      Electric      NaN
# 1              1300.0       541.0    In-line four   four-stroke  6-speed
# 2                 NaN       536.0        Electric      Electric      NaN
# 3                 NaN       536.0        Electric      Electric      NaN
# 4              1300.0       689.0    In-line four   four-stroke  6-speed
#
#    Fuel capacity (lts)                  Fuel system Fuel control  \
# 0                  NaN                          NaN          NaN
# ...

# %%
data['Displacement (ccm)'].describe()
# Out:
# count    37478.000000
# mean       552.513389
# std        545.438118
# min         25.000000
# 25%        125.000000
# 50%        397.000000
# 75%        805.000000
# max       8277.000000
# Name: Displacement (ccm), dtype: float64

# %%
data['Displacement (ccm)'].median()
# Out:
# 397.0

# %%
data['Displacement (ccm)'].fillna(data['Displacement (ccm)'].median(), inplace = True)
data
# Out:
# C:\Users\BG\AppData\Local\Temp\ipykernel_6324\1938203446.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Displacement (ccm)'].fillna(data['Displacement (ccm)'].median(), inplace = True)
#          Brand                Model  Year                   Category  \
# 0      acabion      da vinci 650-vi  2011  Prototype / concept model
# 1      acabion              gtbo 55  2007                      Sport
# 2      acabion  gtbo 600 daytona-vi  2011  Prototype / concept model
# ...

# %%
data['Power (hp)'].describe()
# Out:
# count    26141.000000
# mean        50.741215
# std         52.080878
# min          0.300000
# 25%         12.000000
# 50%         30.000000
# 75%         77.000000
# max        804.000000
# Name: Power (hp), dtype: float64

# %%
data['Power (hp)'].value_counts(dropna=False)
# Out:
# Power (hp)
# NaN      12366
# 27.0       844
# 50.0       584
# 17.0       512
# 100.0      474
#          ...
# 94.5         1
# 50.3         1
# 78.2         1
# 248.0        1
# 52.4         1
# Name: count, Length: 717, dtype: int64

# %%
data['Power (hp)'].mean()
# Out:
# 50.74121494969588

# %%
data['Power (hp)'].fillna(data['Power (hp)'].median(), inplace = True)
data
# Out:
# C:\Users\BG\AppData\Local\Temp\ipykernel_6324\1057063472.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Power (hp)'].fillna(data['Power (hp)'].median(), inplace = True)
#          Brand                Model  Year                   Category  \
# 0      acabion      da vinci 650-vi  2011  Prototype / concept model
# 1      acabion              gtbo 55  2007                      Sport
# 2      acabion  gtbo 600 daytona-vi  2011  Prototype / concept model
# ...

# %%
columnsNames = ['Engine cylinder','Engine stroke','Gearbox','Fuel system','Cooling system','Transmission type'] 
d2 = data.groupby(by = columnsNames).value_counts(dropna=False)
d2
# Out:
# Engine cylinder  Engine stroke  Gearbox    Fuel system                      Cooling system  Transmission type  Brand      Model                Year  Category          Displacement (ccm)  Power (hp)  Fuel capacity (lts)  Fuel control                          Dry weight (kg)  Wheelbase (mm)  Seat height (mm)
# Diesel           Diesel         4-speed    Injection                        Air             Chain              sommer     462                  2014  Allround          462.0               11.0        13.50                NaN                                   180.0            1400.0          760.0               1
#                                                                                                                           diesel 462           2008  Allround          462.0               11.0        NaN                  NaN                                   180.0            NaN             NaN                 1
# ...

# %%
data.dropna(subset = columnsNames, inplace = True)

# %%
data
# Out:
#          Brand                   Model  Year          Category  \
# 6       access     ams 3.20 supercross  2016               ATV
# 7       access  ams 4.30 supermoto efi  2016               ATV
# 8       access  ams 4.38 sm gear shift  2016               ATV
# 9       access  ams 4.38 sx gear shift  2016               ATV
# 10      access          ams 6.46 basic  2016               ATV
# ...        ...                     ...   ...               ...
# 38529  avinton             super snake  2014        Naked bike
# 38530  avinton                 vintage  2014        Naked bike
# 38538     azel                aries 50  2009           Scooter
# 38539     azel                aries 50  2010           Scooter
# 38540     azel               atila 125  2009  Enduro / offroad
#
#        Displacement (ccm)  Power (hp)  Engine cylinder Engine stroke  \
# 6                   280.0        18.8  Single cylinder   four-stroke
# ...

# %%
data['Fuel capacity (lts)'].value_counts(dropna=False)
# Out:
# Fuel capacity (lts)
# NaN      1369
# 17.00     920
# 14.00     752
# 16.00     587
# 12.00     572
#          ...
# 24.22       1
# 25.55       1
# 40.12       1
# 6.51        1
# 18.35       1
# Name: count, Length: 398, dtype: int64

# %%
data['Fuel capacity (lts)'].describe()
# Out:
# count    19413.000000
# mean        13.112708
# std          5.959746
# min          0.500000
# 25%          8.000000
# 50%         13.500000
# 75%         17.030000
# max         50.000000
# Name: Fuel capacity (lts), dtype: float64

# %%
data['Fuel capacity (lts)'].fillna(data['Fuel capacity (lts)'].mean(), inplace = True)
data
# Out:
# C:\Users\BG\AppData\Local\Temp\ipykernel_6324\3233167315.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Fuel capacity (lts)'].fillna(data['Fuel capacity (lts)'].mean(), inplace = True)
#          Brand                   Model  Year          Category  \
# 6       access     ams 3.20 supercross  2016               ATV
# 7       access  ams 4.30 supermoto efi  2016               ATV
# 8       access  ams 4.38 sm gear shift  2016               ATV
# ...

# %%
data['Dry weight (kg)'].value_counts(dropna=False)
# Out:
# Dry weight (kg)
# NaN      8012
# 110.0     149
# 130.0     129
# 120.0     124
# 135.0     116
#          ...
# 251.3       1
# 39.9        1
# 55.3        1
# 545.0       1
# 76.2        1
# Name: count, Length: 1095, dtype: int64

# %%
data['Dry weight (kg)'].fillna(data['Dry weight (kg)'].mean(), inplace = True)
data
# Out:
# C:\Users\BG\AppData\Local\Temp\ipykernel_6324\3653350900.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Dry weight (kg)'].fillna(data['Dry weight (kg)'].mean(), inplace = True)
#          Brand                   Model  Year          Category  \
# 6       access     ams 3.20 supercross  2016               ATV
# 7       access  ams 4.30 supermoto efi  2016               ATV
# 8       access  ams 4.38 sm gear shift  2016               ATV
# 9       access  ams 4.38 sx gear shift  2016               ATV
# ...

# %%
data['Wheelbase (mm)'].value_counts(dropna=False)
# Out:
# Wheelbase (mm)
# NaN       2777
# 1400.0     337
# 1480.0     300
# 1450.0     290
# 1440.0     287
#           ...
# 1203.0       1
# 1051.0       1
# 1169.0       1
# 980.0        1
# 1343.0       1
# Name: count, Length: 600, dtype: int64

# %%
data['Wheelbase (mm)'].fillna(data['Wheelbase (mm)'].mean(),inplace = True)
data
# Out:
# C:\Users\BG\AppData\Local\Temp\ipykernel_6324\3765745859.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Wheelbase (mm)'].fillna(data['Wheelbase (mm)'].mean(),inplace = True)
#          Brand                   Model  Year          Category  \
# 6       access     ams 3.20 supercross  2016               ATV
# 7       access  ams 4.30 supermoto efi  2016               ATV
# 8       access  ams 4.38 sm gear shift  2016               ATV
# 9       access  ams 4.38 sx gear shift  2016               ATV
# ...

# %%
data['Seat height (mm)'].value_counts(dropna=False)
# Out:
# Seat height (mm)
# NaN       3866
# 800.0      811
# 780.0      772
# 790.0      760
# 810.0      641
#           ...
# 887.0        1
# 548.0        1
# 954.0        1
# 951.0        1
# 1000.0       1
# Name: count, Length: 342, dtype: int64

# %%
data['Seat height (mm)'].fillna(data['Seat height (mm)'].mean(), inplace = True)
# Out:
# C:\Users\BG\AppData\Local\Temp\ipykernel_6324\3694204100.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Seat height (mm)'].fillna(data['Seat height (mm)'].mean(), inplace = True)

# %%
# The data after cleaning
data
# Out:
#          Brand                   Model  Year          Category  \
# 6       access     ams 3.20 supercross  2016               ATV
# 7       access  ams 4.30 supermoto efi  2016               ATV
# 8       access  ams 4.38 sm gear shift  2016               ATV
# 9       access  ams 4.38 sx gear shift  2016               ATV
# 10      access          ams 6.46 basic  2016               ATV
# ...        ...                     ...   ...               ...
# 38529  avinton             super snake  2014        Naked bike
# 38530  avinton                 vintage  2014        Naked bike
# 38538     azel                aries 50  2009           Scooter
# 38539     azel                aries 50  2010           Scooter
# 38540     azel               atila 125  2009  Enduro / offroad
#
#        Displacement (ccm)  Power (hp)  Engine cylinder Engine stroke  \
# 6                   280.0        18.8  Single cylinder   four-stroke
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20782 entries, 6 to 38540
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Brand                20782 non-null  object
#  1   Model                20782 non-null  object
#  2   Year                 20782 non-null  object
#  3   Category             20782 non-null  object
#  4   Displacement (ccm)   20782 non-null  float64
#  5   Power (hp)           20782 non-null  float64
#  6   Engine cylinder      20782 non-null  object
#  7   Engine stroke        20782 non-null  object
#  8   Gearbox              20782 non-null  object
#  9   Fuel capacity (lts)  20782 non-null  float64
#  10  Fuel system          20782 non-null  object
#  11  Fuel control         13963 non-null  object
#  12  Cooling system       20782 non-null  object
#  13  Transmission type    20782 non-null  object
#  14  Dry weight (kg)      20782 non-null  float64
# ...

# %%
data.isna()
# Out:
#        Brand  Model   Year  Category  Displacement (ccm)  Power (hp)  \
# 6      False  False  False     False               False       False
# 7      False  False  False     False               False       False
# 8      False  False  False     False               False       False
# 9      False  False  False     False               False       False
# 10     False  False  False     False               False       False
# ...      ...    ...    ...       ...                 ...         ...
# 38529  False  False  False     False               False       False
# 38530  False  False  False     False               False       False
# 38538  False  False  False     False               False       False
# 38539  False  False  False     False               False       False
# 38540  False  False  False     False               False       False
#
#        Engine cylinder  Engine stroke  Gearbox  Fuel capacity (lts)  \
# 6                False          False    False                False
# ...
